# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import psutil
import time

# %%
# %matplotlib notebook
i = 0
x,y = [],[]
fig = plt.figure(figsize=(10,4))
ax = fig.add_subplot(111)
while True:
    x.append(i)
    y.append(psutil.cpu_percent())
    #ax.scatter(x[-1],y[-1])
    ax.plot(x,y,'b-')
    ax.set_xlim(x[-1]-50,x[-1]+50)
    fig.canvas.draw()
    #time.sleep(2)
    i+=1
    #x.pop(0)
    #y.pop(0)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9464/1008261594.py in <module>
#      10     ax.plot(x,y,'b-')
#      11     ax.set_xlim(x[-1]-50,x[-1]+50)
# ---> 12     fig.canvas.draw()
#      13     #time.sleep(2)
#      14     i+=1
#
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_webagg_core.py in draw(self)
#     151         self._png_is_old = True
#     152         try:
# --> 153             super().draw()
#     154         finally:
#     155             self.manager.refresh_all()  # Swap the frames.
#
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     404              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     405               else nullcontext()):
# --> 406             self.figure.draw(self.renderer)
# ...

# %%
df = pd.read_csv("c:/Users/HP-PC/Desktop/DOCS/DATA/Seaborn_Data/tips.csv")

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.shape
# Out:
# (244, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.loc[5,'total_bill']
# Out:
# 25.29

# %%
df.iloc[4,3]
# Out:
# 'No'

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df = pd.read_excel("f:/Data/PythonInternBatch2018-master/Advance_Python/Data_Science/Python/cars.xls")

# %%
df.head()
# Out:
#           Price  Mileage   Make    Model      Trim   Type  Cylinder  Liter  \
# 0  17314.103129     8221  Buick  Century  Sedan 4D  Sedan         6    3.1
# 1  17542.036083     9135  Buick  Century  Sedan 4D  Sedan         6    3.1
# 2  16218.847862    13196  Buick  Century  Sedan 4D  Sedan         6    3.1
# 3  16336.913140    16342  Buick  Century  Sedan 4D  Sedan         6    3.1
# 4  16339.170324    19832  Buick  Century  Sedan 4D  Sedan         6    3.1
#
#    Doors  Cruise  Sound  Leather
# 0      4       1      1        1
# 1      4       1      1        0
# 2      4       1      1        0
# 3      4       1      0        0
# 4      4       1      0        1

# %%
df.isna().sum()
# Out:
# Price       0
# Mileage     0
# Make        0
# Model       0
# Trim        0
# Type        0
# Cylinder    0
# Liter       0
# Doors       0
# Cruise      0
# Sound       0
# Leather     0
# dtype: int64

# %%
d = pd.DataFrame(np.array([45,23,np.nan,22,np.nan,11,33,np.nan]).reshape(4,2))

# %%
d.isna().sum()
# Out:
# 0    2
# 1    1
# dtype: int64

# %%
x = np.array([45,23,np.nan,22,np.nan,11,33,np.nan])

# %%
x
# Out:
# array([45., 23., nan, 22., nan, 11., 33., nan])

# %%
x[[False,False,True,False,True,False,False,True]]
# Out:
# array([nan, nan, nan])

# %%
df[['Price','Mileage']]
# Out:
#             Price  Mileage
# 0    17314.103129     8221
# 1    17542.036083     9135
# 2    16218.847862    13196
# 3    16336.913140    16342
# 4    16339.170324    19832
# ..            ...      ...
# 799  16507.070267    16229
# 800  16175.957604    19095
# 801  15731.132897    20484
# 802  15118.893228    25979
# 803  13585.636802    35662
#
# [804 rows x 2 columns]

# %%
d[1][d[1].isna()] = -22

# %%
m = d[0][d[0]!=-22].mean()

# %%
d[0][d[0] == -22] = m

# %%
d[0].mean()
# Out:
# 39.0

# %%
d
# Out:
#       0     1
# 0  45.0  23.0
# 1  39.0  22.0
# 2  39.0  11.0
# 3  33.0 -22.0

# %%
d[0].mean()
# Out:
# 39.0

# %%
df
# Out:
#             Price  Mileage    Make     Model           Trim   Type  Cylinder  \
# 0    17314.103129     8221   Buick   Century       Sedan 4D  Sedan         6
# 1    17542.036083     9135   Buick   Century       Sedan 4D  Sedan         6
# 2    16218.847862    13196   Buick   Century       Sedan 4D  Sedan         6
# 3    16336.913140    16342   Buick   Century       Sedan 4D  Sedan         6
# 4    16339.170324    19832   Buick   Century       Sedan 4D  Sedan         6
# ..            ...      ...     ...       ...            ...    ...       ...
# 799  16507.070267    16229  Saturn  L Series  L300 Sedan 4D  Sedan         6
# 800  16175.957604    19095  Saturn  L Series  L300 Sedan 4D  Sedan         6
# 801  15731.132897    20484  Saturn  L Series  L300 Sedan 4D  Sedan         6
# 802  15118.893228    25979  Saturn  L Series  L300 Sedan 4D  Sedan         6
# 803  13585.636802    35662  Saturn  L Series  L300 Sedan 4D  Sedan         6
#
#      Liter  Doors  Cruise  Sound  Leather
# ...

# %%
# %matplotlib inline
df.sort_values(by='Mileage',ascending=False)[:5][['Model','Mileage']].plot(kind='bar')
# Out:
# <AxesSubplot:>
